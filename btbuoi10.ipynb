# %%
#w9a1
def merge(a1, a2):
    p1 = 0
    p2 = 0
    ans = []
    while p1<len(a1) and p2<len(a2):
        if a1[p1]<=a2[p2]:
            ans.append(a1[p1])
            p1+=1
        else:
            ans.append(a2[p2])
            p2+=1
    while p1<len(a1):
        ans.append(a1[p1])
        p1+=1
    while p2<len(a2):
        ans.append(a2[p2])
        p2+=1
    return ans

a1 = [int(x) for x in input().split()]
a2 = [int(x) for x in input().split()]

ans = merge(a1, a2)

print(ans)
# Out:
# [0, 1, 1, 1, 1, 1, 1, 2, 2, 2, 3, 3, 4, 4, 5, 6, 7, 8, 9]

# %%
#w9a2
# import heapq
# def find_k(mat, k):
#     m = len(mat)
#     n = len(mat[0])
#     p = [0] * n
#     h = []
#     for i in range(m):
#         heapq.heappush(h, (mat[i][p[i]], i))
#     cur = 0
#     ans = 0
#     while cur<k:
#         cur+=1
#         mi = heapq.heappop(h)
#         ans = mi[0]
#         i = mi[1]
#         p[i]+=1
#         if p[i]>=n: continue
#         heapq.heappush(h, (mat[i][p[i]], i))
#     return ans

def merge(a1, a2):
    p1 = 0
    p2 = 0
    ans = []
    while p1<len(a1) and p2<len(a2):
        if a1[p1]<=a2[p2]:
            ans.append(a1[p1])
            p1+=1
        else:
            ans.append(a2[p2])
            p2+=1
    while p1<len(a1):
        ans.append(a1[p1])
        p1+=1
    while p2<len(a2):
        ans.append(a2[p2])
        p2+=1
    return ans

res = []
def find_k(mat, k, row):
    global res
    if row<len(mat):
        res = merge(res, mat[row])
        find_k(mat, k, row+1)
    return res[k-1]

m, n = map(int, input().split())
mat = []
for i in range(m):
    t = [int(x) for x in input().split()]
    mat.append(t)
k = int(input())

print(find_k(mat, k, 0))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 56
#      53     mat.append(t)
#      54 k = int(input())
# ---> 56 print(find_k(mat, k, 0))
#
# Cell In[13], line 46, in find_k(mat, k, row)
#      44 if row<n-1:
#      45     res = merge(res, mat[row])
# ---> 46     find_k(mat, k, row+1)
#      47 return res[k-1]
#
# Cell In[13], line 46, in find_k(mat, k, row)
#      44 if row<n-1:
#      45     res = merge(res, mat[row])
# ---> 46     find_k(mat, k, row+1)
#      47 return res[k-1]
#
# Cell In[13], line 46, in find_k(mat, k, row)
#      44 if row<n-1:
#      45     res = merge(res, mat[row])
# ---> 46     find_k(mat, k, row+1)
#      47 return res[k-1]
#
# Cell In[13], line 45, in find_k(mat, k, row)
#      43 global res
#      44 if row<n-1:
# ---> 45     res = merge(res, mat[row])
#      46     find_k(mat, k, row+1)
#      47 return res[k-1]
#
# IndexError: list index out of range

# %%
#w9a3
def find_smaller(a):
    a = str(a)
    ans = 0
    for i in range(len(a)):
        for j in range(i+1, len(a)):
            cur = ans()
